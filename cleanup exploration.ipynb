# %%
import json

buildings = None

with open('buildings.json') as f:
    buildings = json.load(f)

# %%
# tl;dr go through each of the entries
# and create one with "BUILDINGS"
collection_by_address = dict()

def full_address(entry):
    return (entry['BLK_NO'], entry['ROAD_NAME'], entry['POSTAL'])

for b in buildings:
    same_address = collection_by_address.setdefault(full_address(b), [])
    same_address.append(b)

# %%
buildings_by_address = [
    (k, [v['BUILDING'] for v in vs])
    for k, vs in collection_by_address.items()
]
buildings_by_address[0]
address_with_multiple_buildings = list(filter(lambda x: len(x[1]) > 1, buildings_by_address))
address_with_multiple_buildings[0:1], len(address_with_multiple_buildings)
# Out:
# ([(('21', 'PARK STREET', '018925'),
#    ['DBS MARINA BAY MRT STATION',
#     'MARINA BAY MRT STATION',
#     'MARINA BAY MRT STATION (NS27)',
#     'OCBC MARINA BAY MRT',
#     'UOB MARINA BAY MRT STATION'])],
#  5985)

# %%
from collections import Counter
import re

def transform(name):
    name = re.sub('\\bMRT STATION', 'MRT', name)
    name = re.sub('^THE\\b', '', name)
    return name

NAUGHTY_NAMES = [
    '\\bKINDERGARTEN\\b',
    '\\bPRESCHOOL\\b',
    '^DBS\\b',
    '^UOB\\b',
    '^CITIBANK\\b',
    '^OCBC\\b',
    '^MAYBANK\\b',
    '^STANDARD CHARTERED BANK\\b',
    '\\bMONTESSORI\\b',
    '\\bPTE\\b',
    '\\bLTD\\b',
    '\\bSKOOL\\b',
    '\\bSTUDENT CARE\\b',
    '\\bNASCANS\\b',
    '\\bCHILD CARE CENTRE\\b',
]

def estimate_weight(name):
    # If a building name ends with "XX BUILDING" it is probably the building name?
    if re.search('\\bBUILDING$', name):
        return 50
    # Annoyingly, Onemap includes all the kindergartens
    # and ATMs, *past and present*. Give these entries much less weight
    if any([re.search(n, name) for n in NAUGHTY_NAMES]):
        return 1
    return 10


def best_building_names(building_names):
    ctr = Counter()

    if len(building_names) <= 1:
        return building_names

    # Drop station IDs in "STATION (EW1)" --
    # most ATM landmarks don't include the station ID, so the
    # station ID prevents the station name from being selected as the
    # most canonical entry
    building_names = [
        re.sub(' STATION \\([A-Z]{2}[0-9]{1,2}( / [A-Z]{2}[0-9]{1,2})*\\)$', ' STATION', name)
        for name in building_names
    ]
    
    # Try to find the most "general" building name, i.e.
    # the name that can be embedded in most other names,
    # after discounting "THE"
    for s in building_names:
        for t in building_names:
            if transform(s) in t:
                ctr.update({s: estimate_weight(s)})
            elif transform(t) in s:
                ctr.update({t: estimate_weight(t)})

    # No embeddings...
    if len(ctr) <= 1:
        return building_names

    # If tied, return all
    top_two = ctr.most_common(2)
    if top_two[1][1] == top_two[0][1]:
        return sorted(building_names, key=lambda x: len(x))
    else:
        return [top_two[0][0]]

def cleanup(n):
    if 'NIL' in n:
        return []
    if 'MULTI STOREY CAR PARK' in n:
        return []
    if 'HDB PUBLIC SHELTERS' in n:
        return []
    if any([re.search('^HDB-', i) for i in n]):
        return []
    if any([re.search('MARKET (AND|&) (HAWKER|FOOD) CENTRE', i) for i in n]):
        return []
    # return n
    return best_building_names(n)

# %%
buildings_by_address = [
    (k, cleanup([v['BUILDING'] for v in vs]))
    for k, vs in collection_by_address.items()
]
buildings_by_address[0]
address_with_multiple_buildings = list(filter(lambda x: len(x[1]) > 1, buildings_by_address))
address_with_multiple_buildings[0:2], len(address_with_multiple_buildings)
# Out:
# ([(('8', 'MARINA VIEW', '018960'),
#    ['DBS ASIA SQUARE',
#     'ASIA SQUARE TOWER 1',
#     'CONSULATE OF THE REPUBLIC OF SLOVENIA',
#     'CONSULATE OF SAINT VINCENT AND THE GRENADINES']),
#   (('12', 'MARINA VIEW', '018961'),
#    ['ASIA SQUARE TOWER 2', 'THE WESTIN SINGAPORE'])],
#  992)

# %%
# Here, I tried fetching the list of ATMs from Onemap
# and using that data to clean the Onemap postcode entries.
# The effectiveness is only around 80% (500+ OCBC ATMs -> 100+ OCBC ATMs)
import json

ocbc = None

with open('./ocbc-atms.json') as f:
    ocbc = json.load(f)

# %%
import re

def maybe_add_ocbc(n):
    if re.search('^OCBC ', n):
        return n.upper().strip()
    return ('OCBC ' + n.upper()).strip()

ocbc_addresses = set([
    maybe_add_ocbc(o['landmark']) for o in ocbc['nearby_ocbc_atms']
])
sorted(ocbc_addresses)
# Out:
# ['OCBC 112 KATONG',
#  'OCBC 313@SOMERSET',
#  'OCBC 7-4 DEPTFORD ROAD',
#  'OCBC ADMIRALTY MRT STATION',
#  'OCBC ADMIRALTY PLACE',
#  'OCBC ALEXANDRA ROAD - FAIRPRICE',
#  'OCBC ALEXANDRA VILLAGE BRANCH',
#  'OCBC ALJUNIED AVENUE 2 - FAIRPRICE',
#  'OCBC ALJUNIED BRANCH',
#  'OCBC ALJUNIED MRT STATION',
#  'OCBC AMARA HOTEL - FAIRPRICE',
#  'OCBC AMK HUB',
#  'OCBC AMOY STREET FOOD CENTRE',
#  'OCBC ANG MO KIO AVENUE 1',
#  'OCBC ANG MO KIO AVENUE 1 - 7-ELEVEN',
#  'OCBC ANG MO KIO AVENUE 1 - FAIRPRICE',
#  'OCBC ANG MO KIO AVENUE 10',
#  'OCBC ANG MO KIO AVENUE 10 - 7-ELEVEN',
#  'OCBC ANG MO KIO AVENUE 10 - CHEERS',
#  'OCBC ANG MO KIO AVENUE 3',
#  'OCBC ANG MO KIO AVENUE 3 - ESSO STATION',
#  'OCBC ANG MO KIO AVENUE 6 - FAIRPRICE',
#  'OCBC ANG MO KIO AVENUE 8 - NANYANG POLYTECHNIC',
#  'OCBC ANG MO KIO BRANCH',
#  'OCBC ANG MO KIO BUS INTERCHANGE',
#  'OCBC ANG MO KIO CENTRAL',
#  'OCBC ANG MO KIO CENTRAL BRANCH',
#  'OCBC ANG MO KIO MRT STATION',
#  'OCBC ASIA SQUARE TOWER 1',
#  'OCBC BALESTIER BRANCH',
#  'OCBC BALESTIER ROAD - CALTEX STATION',
#  'OCBC BALESTIER ROAD - CHEERS',
#  'OCBC BANK OF SINGAPORE',
#  'OCBC BEACH ROAD - CALTEX STATION',
#  'OCBC BEAUTY WORLD MRT STATION',
#  'OCBC BEDOK BRANCH',
#  'OCBC BEDOK BUS INTERCHANGE',
#  'OCBC BEDOK BUS INTERCHANGE EHUB',
#  'OCBC BEDOK MALL - FAIRPRICE',
#  'OCBC BEDOK NORTH',
#  'OCBC BEDOK NORTH BRANCH',
#  'OCBC BEDOK NORTH STREET 1 - FAIRPRICE',
#  'OCBC BEDOK NORTH STREET 4 - FAIRPRICE',
#  'OCBC BEDOK RESERVOIR ROAD - 7-ELEVEN',
#  'OCBC BEDOK RESERVOIR ROAD - FAIRPRICE',
#  'OCBC BEDOK RESERVOIR ROAD - MCDONALDS',
#  'OCBC BENOI - FAIRPRICE',
#  'OCBC BIG BOX',
#  'OCBC BISHAN BRANCH',
#  'OCBC BISHAN MRT STATION',
#  'OCBC BISHAN STREET 11',
#  'OCBC BISHAN STREET 13 -FAIRPRICE',
#  'OCBC BISHAN STREET 22',
#  'OCBC BISHAN STREET 24 - FAIRPRICE',
#  'OCBC BOON KENG MRT STATION',
#  'OCBC BOON LAY BUS INTERCHANGE',
#  'OCBC BOON LAY MRT STATION',
#  'OCBC BOON LAY SHOPPING CENTRE',
#  'OCBC BOTANIC GARDENS MRT STATION',
#  'OCBC BRADDELL MRT STATION',
#  'OCBC BRAS BASAH COMPLEX',
#  'OCBC BRAS BASAH MRT STATION',
#  'OCBC BUANGKOK MRT STATION',
#  'OCBC BUGIS MRT STATION',
#  'OCBC BUGIS+',
#  'OCBC BUKIT BATOK BRANCH',
#  'OCBC BUKIT BATOK CENTRAL',
#  'OCBC BUKIT BATOK EAST AVE 3 - CALTEX STATION',
#  'OCBC BUKIT BATOK EAST AVENUE 3',
#  'OCBC BUKIT BATOK EAST AVENUE 3 - FAIRPRICE',
#  'OCBC BUKIT BATOK MRT STATION',
#  'OCBC BUKIT BATOK STREET 11 - CHEERS',
#  'OCBC BUKIT BATOK WEST AVE 7 - FAIRPRICE',
#  'OCBC BUKIT BATOK WEST AVE 8 - FAIRPRICE',
#  'OCBC BUKIT BATOK WEST AVENUE 6 - 7-ELEVEN',
#  'OCBC BUKIT BATOK WEST AVENUE 8',
#  'OCBC BUKIT GOMBAK MRT STATION',
#  'OCBC BUKIT MERAH CENTRAL - FAIRPRICE',
#  'OCBC BUKIT PANJANG BRANCH',
#  'OCBC BUKIT PANJANG MRT STATION',
#  'OCBC BUKIT PANJANG PLAZA',
#  'OCBC BUKIT PANJANG RING ROAD - 7-ELEVEN',
#  'OCBC BUKIT PANJANG RING ROAD - FAIRPRICE',
#  'OCBC BUKIT TIMAH BRANCH',
#  'OCBC BUKIT TIMAH PLAZA',
#  'OCBC BUKIT TIMAH ROAD - ESSO STATION',
#  'OCBC BUKIT TIMAH ROAD - FAIRPRICE',
#  'OCBC BUONA VISTA MRT STATION',
#  'OCBC BUONA VISTA MRT STATION (CIRCLE LINE)',
#  'OCBC CAMBRIDGE ROAD - FAIRPRICE',
#  'OCBC CANBERRA ROAD - FAIRPRICE',
#  'OCBC CAUSEWAY POINT BRANCH',
#  'OCBC CENTRE BRANCH',
#  'OCBC CENTURY SQUARE - FAIRPRICE',
#  'OCBC CHAI CHEE AVENUE - FAIRPRICE',
#  'OCBC CHAI CHEE ROAD - PRIME SUPERMARKET',
#  'OCBC CHANGI AIRPORT TERMINAL 1',
#  'OCBC CHANGI AIRPORT TERMINAL 2',
#  'OCBC CHANGI AIRPORT TERMINAL 3',
#  'OCBC CHANGI BUSINESS PARK - FAIRPRICE',
#  'OCBC CHANGI CITY POINT',
#  'OCBC CHANGI GENERAL HOSPITAL',
#  'OCBC CHANGI ROAD - 7-ELEVEN',
#  'OCBC CHANGI VILLAGE ROAD - 7-ELEVEN',
#  'OCBC CHEVRON HOUSE',
#  'OCBC CHINATOWN MRT STATION',
#  'OCBC CHINATOWN POINT - FAIRPRICE',
#  'OCBC CHINESE GARDEN MRT STATION',
#  'OCBC CHOA CHU KANG BRANCH',
#  'OCBC CHOA CHU KANG BUS INTERCHANGE',
#  'OCBC CHOA CHU KANG MRT STATION',
#  'OCBC CINELEISURE ORCHARD',
#  'OCBC CIRCUIT ROAD - FAIRPRICE',
#  'OCBC CITY HALL MRT STATION',
#  'OCBC CITY PLAZA',
#  'OCBC CITY SQUARE MALL',
#  'OCBC CITY SQUARE MALL BRANCH',
#  'OCBC CLARKE QUAY MRT STATION',
#  'OCBC CLEMENTI AVENUE 2 - FAIRPRICE',
#  'OCBC CLEMENTI AVENUE 3 - FAIRPRICE',
#  'OCBC CLEMENTI AVENUE 5',
#  'OCBC CLEMENTI BRANCH',
#  'OCBC CLEMENTI BUS INTERCHANGE',
#  'OCBC CLEMENTI MRT STATION',
#  'OCBC CLEMENTI ROAD - NGEE ANN POLYTECHNIC',
#  'OCBC CLEMENTI STREET 11 - 7-ELEVEN',
#  'OCBC CLEMENTI WEST STREET 2 - 7-ELEVEN',
#  'OCBC COLEMAN BRANCH',
#  'OCBC COMMONWEALTH MRT STATION',
#  'OCBC COMPASS ONE BRANCH',
#  'OCBC COMPASS POINT BRANCH',
#  'OCBC COMPASSVALE LINK - FAIRPRICE',
#  'OCBC DAKOTA MRT STATION',
#  'OCBC DAWSON PLACE',
#  'OCBC DEPOT HEIGHTS SHOPPING CENTRE',
#  'OCBC DHOBY GHAUT MRT STATION',
#  'OCBC DOVER CRESCENT - FAIRPRICE',
#  'OCBC DOVER MRT STATION',
#  'OCBC DOWNTOWN EAST',
#  'OCBC DUNEARN ROAD - CALTEX STATION',
#  'OCBC EAST COAST BRANCH',
#  'OCBC EAST COAST ROAD - 7-ELEVEN',
#  'OCBC EAST COAST ROAD - CALTEX STATION',
#  'OCBC EAST COAST ROAD - ESSO STATION',
#  'OCBC EAST COAST ROAD - FAIRPRICE',
#  'OCBC EASTPOINT MALL - FAIRPRICE',
#  'OCBC ENG HOON STREET - CHEERS',
#  'OCBC ESPLANADE MALL',
#  'OCBC ESPLANADE MRT STATION',
#  'OCBC EUNOS CRESCENT - 7-ELEVEN',
#  'OCBC EUNOS CRESCENT - FAIRPRICE',
#  'OCBC EUNOS MRT STATION',
#  'OCBC EXPO DRIVE - SINGAPORE EXPO',
#  'OCBC FAIRPRICE',
#  'OCBC FAJAR SHOPPING CENTRE',
#  'OCBC FAR EAST PLAZA',
#  'OCBC FOCH ROAD - CHEERS',
#  'OCBC FORTUNE CENTRE',
#  'OCBC FORUM THE SHOPPING MALL',
#  'OCBC FRANKEL - ESSO STATION',
#  'OCBC FRENCH ROAD - FAIRPRICE',
#  'OCBC GARDENS BY THE BAY - THE CANOPY',
#  'OCBC GEYLANG BAHRU',
#  'OCBC GEYLANG BRANCH',
#  'OCBC GEYLANG ROAD - 7-ELEVEN',
#  'OCBC GEYLANG ROAD - FAIRPRICE',
#  'OCBC GOLDEN MILE COMPLEX',
#  'OCBC GOLDEN MILE FOOD CENTRE',
#  'OCBC GREAT EASTERN CENTRE',
#  'OCBC GREAT WORLD CITY',
#  'OCBC GREENRIDGE SHOPPING CENTRE',
#  'OCBC GREENWICH V',
#  'OCBC GUARDIAN PHAMARCY',
#  'OCBC HARBOURFRONT BRANCH',
#  'OCBC HARBOURFRONT BUS INTERCHANGE',
#  'OCBC HARBOURFRONT MRT STATION',
#  'OCBC HARBOURFRONT MRT STATION (CIRCLE LINE)',
#  'OCBC HAVELOCK ROAD - FAIRPRICE',
#  'OCBC HAW PAR VILLA MRT STATION',
#  'OCBC HEARTLAND MALL',
#  'OCBC HILLION MALL - FAIRPRICE',
#  'OCBC HOLLAND DRIVE - FAIRPRICE',
#  'OCBC HOLLAND ROAD - CALTEX STATION',
#  'OCBC HOLLAND VILLAGE BRANCH',
#  'OCBC HOLLAND VILLAGE MRT STATION',
#  'OCBC HOUGANG AVENUE 1 - 7-ELEVEN',
#  'OCBC HOUGANG AVENUE 10 - FAIRPRICE',
#  'OCBC HOUGANG AVENUE 3 - CHEERS',
#  'OCBC HOUGANG AVENUE 4 - FAIRPRICE',
#  'OCBC HOUGANG AVENUE 8 - CHEERS',
#  'OCBC HOUGANG BRANCH',
#  'OCBC HOUGANG CAPEVIEW - FAIRPRICE',
#  'OCBC HOUGANG CENTRAL - CHEERS',
#  'OCBC HOUGANG GREEN SHOPPING MALL',
#  'OCBC HOUGANG MALL BRANCH',
#  'OCBC HOUGANG MRT STATION',
#  'OCBC HOUGANG STREET 21 - FAIRPRICE',
#  'OCBC HOUGANG STREET 61',
#  'OCBC HOUGANG STREET 91 - FAIRPRICE',
#  'OCBC IKEA BUILDING',
#  'OCBC IMM BUILDING',
#  'OCBC INTERNATIONAL PLAZA',
#  'OCBC ION ORCHARD',
#  'OCBC ION ORCHARD BRANCH',
#  'OCBC JALAN BESAR BRANCH',
#  'OCBC JALAN BUKIT MERAH - FAIRPRICE',
#  'OCBC JALAN KAYU - FAIRPRICE',
#  'OCBC JALAN SULTAN BRANCH',
#  'OCBC JALAN TIGA - FAIRPRICE',
#  'OCBC JCUBE - FAIRPRICE',
#  'OCBC JELITA SHOPPING CENTRE',
#  'OCBC JEM',
#  'OCBC JOO CHIAT BRANCH',
#  'OCBC JOO CHIAT ROAD - FAIRPRICE',
#  'OCBC JOO KOON BUS INTERCHANGE',
#  'OCBC JOO KOON MRT STATION',
#  'OCBC JUNCTION 8 SHOPPING CENTRE',
#  'OCBC JURONG BRANCH',
#  'OCBC JURONG EAST BRANCH',
#  'OCBC JURONG EAST MRT STATION',
#  'OCBC JURONG EAST STREET 24 - 7-ELEVEN',
#  'OCBC JURONG EAST STREET 24 - FAIRPRICE',
#  'OCBC JURONG EAST STREET 31 - FAIRPRICE',
#  'OCBC JURONG EAST TEMPORARY BUS INTERCHANGE',
#  'OCBC JURONG GATEWAY ROAD - 7-ELEVEN',
#  'OCBC JURONG GATEWAY ROAD - FAIRPRICE',
#  'OCBC JURONG POINT BRANCH',
#  'OCBC JURONG POINT SHOPPING CENTRE',
#  'OCBC JURONG WEST BRANCH',
#  'OCBC JURONG WEST ST 92',
#  'OCBC JURONG WEST ST 93 - CALTEX STATION',
#  'OCBC JURONG WEST STREET 41',
#  'OCBC JURONG WEST STREET 41 - FAIRPRICE',
#  'OCBC JURONG WEST STREET 51 - 7-ELEVEN',
#  'OCBC JURONG WEST STREET 75 - PRIME SUPERMARKET',
#  'OCBC JURONG WEST STREET 91',
#  'OCBC KALLANG BAHRU - FAIRPRICE',
#  'OCBC KALLANG BRANCH',
#  'OCBC KALLANG WAVE',
#  'OCBC KALLANG WAVE BRANCH',
#  'OCBC KATONG BRANCH',
#  'OCBC KATONG V - FAIRPRICE',
#  'OCBC KEMBANGAN MRT STATION',
#  'OCBC KENSINGTON PARK - 7-ELEVEN',
#  'OCBC KENT RIDGE MRT STATION',
#  'OCBC KHATIB BRANCH',
#  'OCBC KHATIB MRT STATION',
#  'OCBC KILLINEY ROAD - FAIRPRICE',
#  'OCBC KIM KEAT AVENUE',
#  'OCBC KIM TIAN ROAD - FAIRPRICE',
#  "OCBC KK WOMEN'S AND CHILDREN'S HOSPITAL",
#  'OCBC KOVAN MRT STATION',
#  'OCBC KRANJI MRT STATION',
#  'OCBC LAKESIDE MRT STATION',
#  'OCBC LAVENDER MRT STATION',
#  'OCBC LAVENDER STREET - ESSO STATION',
#  'OCBC LENGKOK BAHRU - FAIRPRICE',
#  'OCBC LENGKONG TIGA - FAIRPRICE',
#  'OCBC LIANG COURT SHOPPING CENTRE',
#  'OCBC LIMBANG SHOPPING CENTRE',
#  'OCBC LITTLE INDIA ARCADE - 7-ELEVEN',
#  'OCBC LITTLE INDIA MRT STATION',
#  'OCBC LORONG CHUAN - CALTEX STATION',
#  'OCBC LORONG CHUAN - ESSO STATION',
#  'OCBC LORONG CHUAN MRT STATION',
#  'OCBC LORONG LIMAU - FAIRPRICE',
#  'OCBC LORONG MOMBONG - 7-ELEVEN',
#  'OCBC LOT 1 SHOPPERS MALL',
#  'OCBC LOYANG POINT',
#  'OCBC LUCKY PLAZA',
#  'OCBC MACPHERSON MALL - FAIRPRICE',
#  'OCBC MACPHERSON MRT STATION',
#  'OCBC MACPHERSON ROAD - CALTEX STATION',
#  'OCBC MAPLETREE 18 - FAIRPRICE',
#  'OCBC MARINA BAY FINANCIAL CENTRE BRANCH',
#  'OCBC MARINA BAY MRT STATION',
#  'OCBC MARINA BAY SANDS',
#  'OCBC MARINA SQUARE',
#  'OCBC MARINE PARADE CENTRAL',
#  'OCBC MARINE PARADE CENTRAL - FAIRPRICE',
#  'OCBC MARINE PARADE EHUB',
#  'OCBC MARITIME SQUARE',
#  'OCBC MARSILING LANE',
#  'OCBC MARYMOUNT MRT STATION',
#  'OCBC MAXWELL HAWKER CENTRE',
#  'OCBC MINDEF - BUKIT BATOK CAMP',
#  'OCBC MINDEF - DEPOT ROAD CAMP',
#  'OCBC MOUNT ALVERNIA HOSPITAL',
#  'OCBC MOUNT ELIZABETH MEDICAL CENTRE',
#  'OCBC MOUNTBATTEN MRT STATION',
#  'OCBC MOUNTBATTEN SQUARE',
#  'OCBC NANYANG TECHNOLOGICAL UNIVERSITY',
#  'OCBC NATIONAL UNIVERSITY HOSPITAL',
#  'OCBC NATIONAL UNIVERSITY OF SINGAPORE',
#  'OCBC NEW BRIDGE CENTRE',
#  'OCBC NEW BRIDGE ROAD - CHEERS',
#  'OCBC NEW UPPER CHANGI ROAD',
#  'OCBC NEW UPPER CHANGI ROAD - FAIRPRICE',
#  'OCBC NEW WORLD CENTRE',
#  'OCBC NEWTON FOOD CENTRE',
#  'OCBC NEWTON MRT STATION',
#  'OCBC NEX',
#  'OCBC NEX BRANCH',
#  'OCBC NG TENG FONG HOSPITAL',
#  'OCBC NGEE ANN CITY',
#  'OCBC NICOLL HIGHWAY MRT STATION',
#  'OCBC NORTH BRANCH',
#  'OCBC NORTHPOINT',
#  'OCBC NORTHPOINT BRANCH',
#  'OCBC NOVENA MRT STATION',
#  'OCBC NTU BRANCH',
#  'OCBC NTU FRANK STORE',
#  'OCBC NUH - FAIRPRICE',
#  'OCBC NUS',
#  'OCBC NUS FRANK STORE',
#  'OCBC NUS UNIVERSITY TOWN - CHEERS',
#  'OCBC ONAN ROAD - CHEERS',
#  'OCBC ONE-NORTH MRT STATION',
#  'OCBC ORCHARD MRT STATION',
#  'OCBC ORCHARD POINT BRANCH',
#  'OCBC ORCHARDGATEWAY',
#  'OCBC ORCHARDGATEWAY BRANCH',
#  'OCBC ORCHID COUNTRY CLUB - FAIRPRICE',
#  'OCBC OUR TAMPINES HUB - FAIRPRICE',
#  'OCBC OUTRAM PARK MRT STATION (NEL)',
#  'OCBC PARAGON',
#  'OCBC PARCO BUGIS JUNCTION',
#  'OCBC PARKLANE SHOPPING MALL',
#  'OCBC PARKWAY PARADE',
#  'OCBC PASIR RIS BUS INTERCHANGE',
#  'OCBC PASIR RIS DRIVE 4 - GIANT',
#  'OCBC PASIR RIS DRIVE 6 - 7-ELEVEN',
#  'OCBC PASIR RIS MRT STATION',
#  'OCBC PASIR RIS WEST PLAZA',
#  'OCBC PASIR RIS WEST PLAZA - FAIRPRICE',
#  'OCBC PAYA LEBAR MRT STATION',
#  'OCBC PAYA LEBAR MRT STATION (CIRCLE LINE)',
#  'OCBC PAYA LEBAR SQUARE',
#  'OCBC PENINSULA PLAZA',
#  "OCBC PEOPLE'S PARK CENTRE",
#  "OCBC PEOPLE'S PARK COMPLEX",
#  'OCBC PEOPLES PARK BRANCH',
#  'OCBC PEOPLES PARK FOOD CENTRE',
#  'OCBC PIONEER MALL',
#  'OCBC PIONEER MRT STATION',
#  'OCBC PIONEER ROAD - ESSO STATION',
#  'OCBC PLAZA SINGAPURA',
#  'OCBC POTONG PASIR - FAIRPRICE',
#  'OCBC POTONG PASIR MRT STATION',
#  'OCBC PROMENADE MRT STATION',
#  'OCBC PUNGGOL BUS INTERCHANGE',
#  'OCBC PUNGGOL DRIVE - FAIRPRICE',
#  'OCBC PUNGGOL FIELD',
#  'OCBC PUNGGOL MRT STATION',
#  'OCBC PUNGGOL PLAZA',
#  'OCBC PUNGGOL PLAZA BRANCH',
#  'OCBC PUNGGOL WATERWAY TERRACE - FAIRPRICE',
#  'OCBC QUEENSTOWN MRT STATION',
#  'OCBC QUEENSWAY SHOPPING CENTRE',
#  'OCBC RAFFLES CITY SHOPPING CENTRE',
#  'OCBC RAFFLES PLACE MRT STATION',
#  'OCBC REPUBLIC POLYTECHNIC',
#  'OCBC RESORTS WORLD AT SENTOSA',
#  'OCBC RIVER VALLEY ROAD - 7-ELEVEN',
#  'OCBC RIVER VALLEY ROAD - FAIRPRICE',
#  'OCBC RIVERVALE MALL',
#  'OCBC RIVERVALE PLAZA',
#  'OCBC ROBINSON ROAD BRANCH',
#  'OCBC ROCHOR MRT STATION',
#  'OCBC SCOTTS SQUARE',
#  'OCBC SELETAR MALL - FAIRPRICE',
#  'OCBC SEMBAWANG MRT STATION',
#  'OCBC SEMBAWANG SHOPPING CENTRE',
#  'OCBC SEMBAWANG WAY - FAIRPRICE',
#  'OCBC SENG POH ROAD - 7-ELEVEN',
#  'OCBC SENGKANG BUS INTERCHANGE',
#  'OCBC SENGKANG EAST AVE - FAIRPRICE',
#  'OCBC SENGKANG MRT STATION',
#  'OCBC SENGKANG SQUARE - KOPITIAM SQUARE',
#  'OCBC SENJA ROAD - FAIRPRICE',
#  'OCBC SENTOSA',
#  'OCBC SENTOSA COVE',
#  'OCBC SERANGOON AVENUE 3 - 7-ELEVEN',
#  'OCBC SERANGOON BUS INTERCHANGE',
#  'OCBC SERANGOON CENTRAL DRIVE - FAIRPRICE',
#  'OCBC SERANGOON GARDEN BRANCH',
#  'OCBC SERANGOON MRT STATION',
#  'OCBC SERANGOON NORTH AVENUE 1 - FAIRPRICE',
#  'OCBC SERANGOON NORTH AVENUE 5 - SHENG SIONG',
#  'OCBC SERANGOON ROAD - 7-ELEVEN',
#  'OCBC SHAW CENTRE',
#  'OCBC SHAW PLAZA - TWIN HEIGHTS',
#  'OCBC SHUN LI INDUSTRIAL PARK',
#  'OCBC SILAT AVE - FAIRPRICE',
#  'OCBC SIM LIM SQUARE',
#  'OCBC SIM LIM TOWER',
#  'OCBC SIMEI MRT STATION',
#  'OCBC SIMEI STREET 3',
#  'OCBC SIMS PLACE',
#  'OCBC SINGAPORE GENERAL HOSPITAL',
#  'OCBC SINGAPORE INSTITUTE OF MANAGEMENT',
#  'OCBC SINGAPORE POLYTECHNIC',
#  'OCBC SINGAPORE POLYTECHNIC BRANCH (FRANK)',
#  'OCBC SINGAPORE POLYTECHNIC FRANK STORE',
#  'OCBC SINGAPORE PRESS HOLDINGS',
#  'OCBC SINGAPORE UNIVERSITY OF TECHNOLOGY AND DESIGN',
#  'OCBC SIXTH AVENUE - 7-ELEVEN',
#  'OCBC SIXTH AVENUE BRANCH',
#  'OCBC SMU BRANCH',
#  'OCBC SOMERSET MRT STATION EHUB',
#  'OCBC SOUTH BRIDGE ROAD - FOOK HAI BUILDING',
#  'OCBC SOUTH WOODLANDS DRIVE - FAIRPRICE',
#  'OCBC SQUARE 2 - FAIRPRICE',
#  'OCBC STADIUM STATION',
#  'OCBC STAMFORD ROAD - CHEERS',
#  'OCBC STIRLING ROAD - FAIRPRICE',
#  'OCBC SUN PLAZA - FAIRPRICE',
#  'OCBC SUN PLAZA BRANCH',
#  'OCBC SUNSHINE PLACE',
#  'OCBC SUNTEC CITY',
#  'OCBC SUNTEC CITY BRANCH',
#  'OCBC TAI SENG MRT STATION',
#  'OCBC TAMAN JURONG SHOPPING CENTRE',
#  'OCBC TAMPINES 1',
#  'OCBC TAMPINES AVE 8 - CALTEX STATION',
#  'OCBC TAMPINES AVENUE 1 - CHEERS',
#  'OCBC TAMPINES BRANCH',
#  'OCBC TAMPINES BUS INTERCHANGE',
#  'OCBC TAMPINES CENTRAL 1',
#  'OCBC TAMPINES CENTRAL COMMUNITY CENTRE',
#  'OCBC TAMPINES CENTRE TWO',
#  'OCBC TAMPINES MALL',
#  'OCBC TAMPINES MART',
#  'OCBC TAMPINES MRT STATION',
#  'OCBC TAMPINES SOUTH BRANCH',
#  'OCBC TAMPINES STREET 11 - 7-ELEVEN',
#  'OCBC TAMPINES STREET 11 - FAIRPRICE',
#  'OCBC TAMPINES STREET 21',
#  'OCBC TAMPINES STREET 44',
#  'OCBC TAMPINES STREET 81 - PRIME SUPERMARKET',
#  'OCBC TAN TOCK SENG HOSPITAL',
#  'OCBC TANAH MERAH FERRY TERMINAL',
#  'OCBC TANAH MERAH MRT STATION',
#  'OCBC TANG PLAZA',
#  'OCBC TANGJONG PAGAR PLAZA',
#  'OCBC TANGLIN MALL',
#  'OCBC TANJONG KATONG ROAD - 7-ELEVEN',
#  'OCBC TANJONG PAGAR MRT STATION',
#  'OCBC TANJONG PAGAR PLAZA - 7-ELEVEN',
#  'OCBC TANJONG PAGAR ROAD',
#  'OCBC TEBAN GARDENS ROAD',
#  'OCBC TEBAN PLACE',
#  'OCBC TECK WHYE LANE - FAIRPRICE',
#  'OCBC TELOK BLANGAH MRT STATION',
#  'OCBC TELOK BLANGAH STREET 32 - FAIRPRICE',
#  'OCBC THE CATHAY',
#  'OCBC THE CENTRAL',
#  'OCBC THE CENTREPOINT',
#  'OCBC THE CLEMENTI MALL',
#  'OCBC THE SIGNATURE',
#  'OCBC THE STAR VISTA',
#  'OCBC THOMSON BRANCH',
#  'OCBC THOMSON PLAZA',
#  'OCBC TIONG BAHRU MRT STATION',
#  'OCBC TIONG BAHRU PLAZA BRANCH',
#  'OCBC TOA PAYOH BUS INTERCHANGE',
#  'OCBC TOA PAYOH CENTRAL BRANCH',
#  'OCBC TOA PAYOH LORONG 1',
#  'OCBC TOA PAYOH LORONG 1 - 7-ELEVEN',
#  'OCBC TOA PAYOH LORONG 2 - ESSO STATION',
#  'OCBC TOA PAYOH LORONG 4 - FAIRPRICE',
#  'OCBC TOA PAYOH LORONG 6 - 7-ELEVEN',
#  'OCBC TOA PAYOH LORONG 6 - FAIRPRICE',
#  'OCBC TOA PAYOH LORONG 8',
#  'OCBC TOA PAYOH MRT STATION',
#  'OCBC TOA PAYOH MRT STATION EHUB',
#  'OCBC TOWNER ROAD - 7-ELEVEN',
#  'OCBC UBI AVENUE 1 - GIANT',
#  'OCBC UBI BUSINESS BANKING CENTRE',
#  'OCBC UNITED SQUARE BRANCH',
#  'OCBC UPPER ALJUNIED ROAD - PRIME SUPERMARKET',
#  'OCBC UPPER BOON KENG ROAD',
#  'OCBC UPPER BOON KENG ROAD - FAIRPRICE',
#  'OCBC UPPER BUKIT TIMAH ROAD - ESSO STATION',
#  'OCBC UPPER SERANGOON ROAD - CALTEX STATION',
#  'OCBC UPPER THOMSON ROAD - 7-ELEVEN',
#  'OCBC UPPER THOMSON ROAD - ESSO STATION',
#  'OCBC V HOTEL',
#  'OCBC VISTA POINT',
#  'OCBC VIVOCITY FRANK STORE',
#  'OCBC WATERWAY POINT - FAIRPRICE',
#  'OCBC WATERWAY POINT BRANCH',
#  'OCBC WEST COAST DRIVE - 7-ELEVEN',
#  'OCBC WEST COAST DRIVE - FAIRPRICE',
#  'OCBC WEST COAST PLAZA',
#  'OCBC WESTGATE',
#  'OCBC WHITE SANDS',
#  'OCBC WHITE SANDS BRANCH',
#  'OCBC WISMA ATRIA',
#  'OCBC WOODLANDS AVE 1 - FAIRPRICE<BR>',
#  'OCBC WOODLANDS AVENUE 1 - FAIRPRICE',
#  'OCBC WOODLANDS AVENUE 3 - FAIRPRICE',
#  'OCBC WOODLANDS BRANCH',
#  'OCBC WOODLANDS CENTRE ROAD',
#  'OCBC WOODLANDS DRIVE 50 - FAIRPRICE',
#  'OCBC WOODLANDS MART',
#  'OCBC WOODLANDS MRT STATION',
#  'OCBC WOODLANDS NORTH PLAZA',
#  'OCBC WOODLANDS TEMPORARY BUS INTERCHANGE',
#  'OCBC YEW TEE MRT STATION',
#  'OCBC YEW TEE SQUARE',
#  'OCBC YISHUN AVENUE 5 - 7-ELEVEN',
#  'OCBC YISHUN BRANCH',
#  'OCBC YISHUN CENTRAL - CHEERS',
#  'OCBC YISHUN MRT STATION',
#  'OCBC YISHUN RING ROAD',
#  'OCBC YISHUN RING ROAD - 7-ELEVEN',
#  'OCBC YISHUN RING ROAD - CALTEX STATION',
#  'OCBC YISHUN RING ROAD - FAIRPRICE',
#  'OCBC YISHUN STREET 22 - 7-ELEVEN',
#  'OCBC YISHUN STREET 72',
#  'OCBC YISHUN TEMP BUS INTERCHANGE',
#  'OCBC YUAN CHING ROAD - SHENG SIONG SUPERMARKET',
#  'OCBC YUNG KUANG ROAD - FAIRPRICE',
#  'OCBC ZHONGSHAN PARK - FAIRPRICE']

# %%
import re

ocbc_atms = sorted([
    b
    for a in address_with_multiple_buildings
    for b in a[1]
    if re.search('^OCBC ', b)
])
ocbc_atms
# Out:
# ['OCBC 313@SOMERSET',
#  'OCBC 7-4 DEPTFORD ROAD',
#  'OCBC ADMIRALTY MRT',
#  'OCBC ADMIRALTY PLACE',
#  'OCBC ALEXANDRA RD - FAIRPRICE',
#  'OCBC ALJUNIED AVE 2 - FAIRPRICE',
#  'OCBC ALJUNIED MRT',
#  'OCBC AMARA HOTEL - FAIRPRICE',
#  'OCBC AMK HUB',
#  'OCBC AMOY STREET FOOD CENTRE',
#  'OCBC ANG MO KIO AVE 1',
#  'OCBC ANG MO KIO AVE 1 - 7 ELEVEN',
#  'OCBC ANG MO KIO AVE 1 - FAIRPRICE',
#  'OCBC ANG MO KIO AVE 10',
#  'OCBC ANG MO KIO AVE 10 - 7 ELEVEN',
#  'OCBC ANG MO KIO AVE 10 - CHEERS',
#  'OCBC ANG MO KIO AVE 3',
#  'OCBC ANG MO KIO AVE 3 - ESSO STATION',
#  'OCBC ANG MO KIO AVE 6 - FAIRPRICE',
#  'OCBC ANG MO KIO AVE 8 - NANYANG POLYTECHNIC',
#  'OCBC ANG MO KIO BRANCH',
#  'OCBC ANG MO KIO BUS INTERCHANGE',
#  'OCBC ANG MO KIO MRT STATION',
#  'OCBC ASIA SQUARE TOWER 1',
#  'OCBC BALESTIER ROAD - CALTEX STATION',
#  'OCBC BALESTIER ROAD - CHEERS',
#  'OCBC BANK OF SINGAPORE',
#  'OCBC BEACH ROAD - CALTEX STATION',
#  'OCBC BEAUTY WORLD MRT STATION',
#  'OCBC BEDOK BRANCH',
#  'OCBC BEDOK BUS INTERCHANGE',
#  'OCBC BEDOK MALL - FAIRPRICE',
#  'OCBC BEDOK NORTH',
#  'OCBC BEDOK NORTH BRANCH',
#  'OCBC BEDOK NORTH ST 1 - FAIRPRICE',
#  'OCBC BEDOK NORTH ST 4 - FAIRPRICE',
#  'OCBC BEDOK RESERVOIR RD - 7 ELEVEN',
#  'OCBC BEDOK RESERVOIR RD - FAIRPRICE',
#  'OCBC BEDOK RESERVOIR RD - MCDONALDS',
#  'OCBC BENDEMEER ROAD - FAIRPRICE',
#  'OCBC BENOI RD- FAIRPRICE',
#  'OCBC BISHAN MRT STATION',
#  'OCBC BISHAN ST 13 - FAIRPRICE',
#  'OCBC BISHAN ST 22',
#  'OCBC BISHAN ST 24 - FAIRPRICE',
#  'OCBC BISHAN STREET 11',
#  'OCBC BOON KENG MRT',
#  'OCBC BOON LAY BUS INTERCHANGE',
#  'OCBC BOON LAY MRT STATION',
#  'OCBC BOON LAY SHOPPING CENTRE',
#  'OCBC BOON LAY SHOPPING CENTRE FAIRPRICE',
#  'OCBC BOTANIC GARDENS MRT STATION',
#  'OCBC BRADDELL MRT STATION',
#  'OCBC BRAS BASAH COMPLEX',
#  'OCBC BRAS BASAH MRT STATION',
#  'OCBC BUANGKOK MRT STATION',
#  'OCBC BUGIS MRT STATION',
#  'OCBC BUGIS+',
#  'OCBC BUKIT BATOK BUSINESS BANKING CENTRE',
#  'OCBC BUKIT BATOK CENTRAL - 7-ELEVEN',
#  'OCBC BUKIT BATOK CENTRAL - BT BATOK BRANCH',
#  'OCBC BUKIT BATOK EAST AVE 3 - FAIRPRICE',
#  'OCBC BUKIT BATOK MRT',
#  'OCBC BUKIT BATOK MRT STATION - FAIRPRICE',
#  'OCBC BUKIT BATOK ST 11 - CHEERS',
#  'OCBC BUKIT BATOK WEST AVE 6 - 7 ELEVEN',
#  'OCBC BUKIT BATOK WEST AVE 7 - FAIRPRICE',
#  'OCBC BUKIT BATOK WEST AVE 8',
#  'OCBC BUKIT BATOK WEST AVE 8 - FAIRPRICE',
#  'OCBC BUKIT GOMBAK MRT STATION',
#  'OCBC BUKIT MERAH CENTRAL - FAIRPRICE',
#  'OCBC BUKIT PANJANG BRANCH',
#  'OCBC BUKIT PANJANG BUS INTERCHANGE',
#  'OCBC BUKIT PANJANG MRT STATION',
#  'OCBC BUKIT PANJANG PLAZA',
#  'OCBC BUKIT PANJANG RING RD - 7 ELEVEN',
#  'OCBC BUKIT TIMAH - SINOPEC STATION',
#  'OCBC BUKIT TIMAH BRANCH',
#  'OCBC BUKIT TIMAH PLAZA - FAIRPRICE',
#  'OCBC BUKIT TIMAH RD - FAIRPRICE',
#  'OCBC BUKIT TIMAH ROAD - ESSO STATION',
#  'OCBC BUONA VISTA MRT STATION',
#  'OCBC BUONA VISTA MRT STATION (CIRCLE LINE)',
#  'OCBC CAMBRIDGE ROAD - FAIRPRICE',
#  'OCBC CAMPUS',
#  'OCBC CANBERRA ROAD - FAIRPRICE',
#  'OCBC CAUSEWAY POINT BRANCH',
#  'OCBC CENTRE',
#  'OCBC CHAI CHEE AVENUE - FAIRPRICE',
#  'OCBC CHAI CHEE ROAD - PRIME SUPERMARKET',
#  'OCBC CHANGI AIRPORT TERMINAL 1 - ARRIVAL HALL CENTRAL',
#  'OCBC CHANGI AIRPORT TERMINAL 1 - DEPARTURE HALL',
#  'OCBC CHANGI AIRPORT TERMINAL 1 - DEPARTURE TRANSIT EAST',
#  'OCBC CHANGI AIRPORT TERMINAL 2 - ARRIVAL HALL NORTH',
#  'OCBC CHANGI AIRPORT TERMINAL 2 - ARRIVAL HALL SOUTH',
#  'OCBC CHANGI AIRPORT TERMINAL 2 - DEPARTURE/CHECK-IN HALL NORTH',
#  'OCBC CHANGI AIRPORT TERMINAL 2 - DEPARTURE/TRANSIT LOUNGE SOUTH',
#  'OCBC CHANGI AIRPORT TERMINAL 2 - DEPARTURE/TRANSIT NORTH',
#  'OCBC CHANGI AIRPORT TERMINAL 3 - ARRIVAL HALL NORTH',
#  'OCBC CHANGI AIRPORT TERMINAL 3 - BASEMENT 2 SOUTH (IN FRONT OF FOODCOURT)',
#  'OCBC CHANGI AIRPORT TERMINAL 3 - DEPARTURE CHECK-IN HALL NORTH',
#  'OCBC CHANGI AIRPORT TERMINAL 3 - DEPARTURE CHECK-IN HALL SOUTH',
#  'OCBC CHANGI AIRPORT TERMINAL 3 - DEPARTURE TRANSIT SOUTH CENTRAL',
#  'OCBC CHANGI AIRPORT TERMINAL 4 - ARRIVAL HALL',
#  'OCBC CHANGI AIRPORT TERMINAL 4 - DEPARTURE HALL',
#  'OCBC CHANGI AIRPORT TERMINAL 4 - DEPARTURE TRANSIT',
#  'OCBC CHANGI AIRPORT TERMINAL 4 - LEVEL 2 NEAR FOOD COURT',
#  'OCBC CHANGI BUSINESS PARK - FAIRPRICE',
#  'OCBC CHANGI CITY POINT - FAIRPRICE',
#  'OCBC CHANGI GENERAL HOSPITAL',
#  'OCBC CHANGI ROAD - 7 ELEVEN',
#  'OCBC CHANGI VILLAGE ROAD - 7 ELEVEN',
#  'OCBC CHINATOWN MRT STATION',
#  'OCBC CHINATOWN POINT - FAIRPRICE',
#  'OCBC CHINESE GARDEN MRT STATION',
#  'OCBC CHOA CHU KANG BRANCH',
#  'OCBC CHOA CHU KANG MRT STATION',
#  'OCBC CINELEISURE ORCHARD',
#  'OCBC CIRCUIT ROAD - FAIRPRICE',
#  'OCBC CITY HALL MRT STATION',
#  'OCBC CITY PLAZA',
#  'OCBC CITY SQUARE MALL - BRANCH',
#  'OCBC CITY SQUARE MALL - FAIRPRICE',
#  'OCBC CLARKE QUAY MRT STATION',
#  'OCBC CLEMENTI AVENUE 2 -FAIRPRICE',
#  'OCBC CLEMENTI AVENUE 3 - FAIRPRICE',
#  'OCBC CLEMENTI AVENUE 5',
#  'OCBC CLEMENTI BUS INTERCHANGE',
#  'OCBC CLEMENTI MRT STATION',
#  'OCBC CLEMENTI ST 11 - 7 ELEVEN',
#  'OCBC CLEMENTI WEST ST 2',
#  'OCBC COMMONWEALTH MRT STATION',
#  'OCBC COMPASS ONE BRANCH',
#  'OCBC COMPASSVALE LINK - FAIRPRICE',
#  'OCBC DAKOTA MRT STATION',
#  'OCBC DAWSON PLACE',
#  'OCBC DEPOT HEIGHTS SHOPPING CENTRE',
#  'OCBC DHOBY GHAUT MRT STATION',
#  'OCBC DOVER CRESCENT - FAIRPRICE',
#  'OCBC DOVER MRT STATION',
#  'OCBC DOWNTOWN EAST - FAIRPRICE',
#  'OCBC DOWNTOWN EAST - MARKET SQUARE@DOWNTOWN EAST',
#  'OCBC DUNEARN ROAD - CALTEX STATION',
#  'OCBC EAST COAST ROAD - 7 ELEVEN',
#  'OCBC EAST COAST ROAD - CALTEX STATION',
#  'OCBC EAST COAST ROAD - ESSO STATION',
#  'OCBC EAST COAST ROAD - FAIRPRICE',
#  'OCBC EASTPOINT MALL - FAIRPRICE',
#  'OCBC ENG HOON ST - CHEERS',
#  'OCBC ESPLANADE MALL',
#  'OCBC ESPLANADE MRT STATION',
#  'OCBC EUNOS CRESCENT - 7 ELEVEN',
#  'OCBC EUNOS CRESCENT - FAIRPRICE',
#  'OCBC EUNOS MRT STATION',
#  'OCBC EXPO DRIVE - SINGAPORE EXPO',
#  'OCBC FAJAR SHOPPING CENTRE',
#  'OCBC FAR EAST PLAZA',
#  'OCBC FOCH ROAD - CHEERS',
#  'OCBC FORTUNE CENTRE',
#  'OCBC FORUM THE SHOPPING MALL',
#  'OCBC FRANKEL - ESSO STATION',
#  'OCBC FRENCH ROAD - FAIRPRICE',
#  'OCBC GARDENS BY THE BAY - THE CANOPY',
#  'OCBC GEYLANG BAHRU',
#  'OCBC GEYLANG ROAD - 7 ELEVEN',
#  'OCBC GHIM MOH LINK - FAIRPRICE',
#  'OCBC GOLDEN MILE COMPLEX',
#  'OCBC GOLDEN MILE FOOD CENTRE',
#  'OCBC GREAT EASTERN CENTRE',
#  'OCBC GREENRIDGE SHOPPING CENTRE',
#  'OCBC GREENWICH V',
#  'OCBC GUARDIAN PHARMACY',
#  'OCBC HARBOURFRONT BUS INTERCHANGE',
#  'OCBC HARBOURFRONT MRT STATION',
#  'OCBC HARBOURFRONT MRT STATION (CIRCLE LINE)',
#  'OCBC HAVELOCK ROAD - FAIRPRICE',
#  'OCBC HAW PAR VILLA MRT STATION',
#  'OCBC HEARTLAND MALL',
#  'OCBC HILLION MALL - FAIRPRICE',
#  'OCBC HOLLAND DRIVE - FAIRPRICE',
#  'OCBC HOLLAND ROAD - CALTEX STATION',
#  'OCBC HOLLAND VILAGE MRT STATION',
#  'OCBC HOLLAND VILLAGE BRANCH',
#  'OCBC HOUGANG AVE 1 - 7 ELEVEN',
#  'OCBC HOUGANG AVE 10 - FAIRPRICE',
#  'OCBC HOUGANG AVE 3 - CHEERS',
#  'OCBC HOUGANG AVE 4 - FAIRPRICE',
#  'OCBC HOUGANG AVE 8 - CHEERS',
#  'OCBC HOUGANG BRANCH',
#  'OCBC HOUGANG CAPEVIEW - FAIRPRICE',
#  'OCBC HOUGANG CENTRAL - CHEERS',
#  'OCBC HOUGANG GREEN SHOPPING MALL',
#  'OCBC HOUGANG MALL BRANCH',
#  'OCBC HOUGANG MRT STATION',
#  'OCBC HOUGANG ST 21 - FAIRPRICE',
#  'OCBC HOUGANG ST 61',
#  'OCBC HOUGANG ST 91 - FAIRPRICE',
#  'OCBC IKEA BUILDING',
#  'OCBC IKEA BUILDING',
#  'OCBC IMM BUILDING - NEAR FOOD KIOSK SECTION',
#  'OCBC IMM BUILDING - NEAR GIANT SUPERMARKET',
#  'OCBC INTERNATIONAL PLAZA',
#  'OCBC ION ORCHARD',
#  'OCBC ION ORCHARD BRANCH',
#  'OCBC JALAN BUKIT MERAH - FAIRPRICE',
#  'OCBC JALAN KAYU - FAIRPRICE',
#  'OCBC JALAN TIGA - FAIRPRICE',
#  'OCBC JCUBE - FAIRPRICE',
#  'OCBC JEM - FAIRPRICE',
#  'OCBC JEM - JURONG EAST BRANCH',
#  'OCBC JOO CHIAT ROAD - FAIRPRICE',
#  'OCBC JOO KOON BUS INTERCHANGE',
#  'OCBC JOO KOON MRT STATION',
#  'OCBC JUNCTION 10',
#  'OCBC JUNCTION 8 SHOPPING CENTRE',
#  'OCBC JURONG BRANCH',
#  'OCBC JURONG EAST MRT',
#  'OCBC JURONG EAST ST 24 - 7 ELEVEN',
#  'OCBC JURONG EAST ST 24 - FAIRPRICE',
#  'OCBC JURONG EAST ST 31 - FAIRPRICE',
#  'OCBC JURONG EAST TEMPORARY BUS INTERCHANGE',
#  'OCBC JURONG GATEWAY ROAD - 7 ELEVEN',
#  'OCBC JURONG GATEWAY ROAD - FAIRPRICE',
#  'OCBC JURONG POINT SHOPPING CENTRE',
#  'OCBC JURONG POINT SHOPPING CENTRE',
#  'OCBC JURONG WEST BRANCH',
#  'OCBC JURONG WEST ST 41',
#  'OCBC JURONG WEST ST 41 - FAIRPRICE',
#  'OCBC JURONG WEST ST 51 - 7 ELEVEN',
#  'OCBC JURONG WEST ST 75 - PRIME SUPERMARKET',
#  'OCBC JURONG WEST ST 91',
#  'OCBC JURONG WEST ST 92',
#  'OCBC KALLANG BAHRU - FAIRPRICE',
#  'OCBC KALLANG WAVE',
#  'OCBC KATONG V - FAIRPRICE',
#  'OCBC KEMBANGAN MRT',
#  'OCBC KENSINGTON PARK - 7 ELEVEN',
#  'OCBC KENT RIDGE MRT',
#  'OCBC KHATIB MRT',
#  'OCBC KILLINEY ROAD - FAIRPRICE',
#  'OCBC KIM KEAT AVENUE',
#  'OCBC KIM TIAN ROAD - FAIRPRICE',
#  "OCBC KK WOMEN'S AND CHILDREN'S HOSPITAL",
#  'OCBC KOVAN MRT',
#  'OCBC KRANJI MRT',
#  'OCBC LAKESIDE MRT',
#  'OCBC LAVENDER MRT',
#  'OCBC LAVENDER STREET - ESSO STATION',
#  'OCBC LENGKOK BAHRU - FAIRPRICE',
#  'OCBC LENGKONG TIGA - FAIRPRICE',
#  'OCBC LIANG COURT SHOPPING CENTRE',
#  'OCBC LIMBANG SHOPPING CENTRE',
#  'OCBC LITTLE INDIA ARCADE - 7 ELEVEN',
#  'OCBC LITTLE INDIA MRT',
#  'OCBC LORONG CHUAN - ESSO STATION',
#  'OCBC LORONG CHUAN MRT',
#  'OCBC LORONG LIMAU - FAIRPRICE',
#  'OCBC LORONG MOMBONG - 7 ELEVEN',
#  'OCBC LOT 1 SHOPPERS MALL',
#  'OCBC LOYANG POINT',
#  'OCBC LUCKY PLAZA',
#  'OCBC MACPHERSON MALL - FAIRPRICE',
#  'OCBC MACPHERSON MRT',
#  'OCBC MARINA BAY FINANCIAL CENTRE BRANCH',
#  'OCBC MARINA BAY LINK MALL',
#  'OCBC MARINA BAY MRT',
#  'OCBC MARINA BAY SANDS',
#  'OCBC MARINA SQUARE',
#  'OCBC MARINE PARADE CENTRAL',
#  'OCBC MARINE PARADE CENTRAL - FAIRPRICE',
#  'OCBC MARITIME SQUARE',
#  'OCBC MARSILING LANE',
#  'OCBC MARYMOUNT MRT',
#  'OCBC MAXWELL HAWKER CENTRE',
#  'OCBC MINDEF - BUKIT BATOK CAMP',
#  'OCBC MINDEF - DEPOT ROAD CAMP',
#  'OCBC MOUNBATTEN MRT',
#  'OCBC MOUNBATTEN SQUARE',
#  'OCBC MOUNT ALVERNIA HOSPITAL',
#  'OCBC MOUNT ELIZABETH MEDICAL CENTRE',
#  'OCBC NANYANG TECHNOLOGICAL UNIVERSITY',
#  'OCBC NATIONAL UNIVERSITY HOSPITAL',
#  'OCBC NATIONAL UNIVERSITY OF SINGAPORE',
#  'OCBC NEW BRIDGE CENTRE',
#  'OCBC NEW BRIDGE ROAD - CHEERS',
#  'OCBC NEW UPPER CHANGI ROAD',
#  'OCBC NEW UPPER CHANGI ROAD - FAIRPRICE',
#  'OCBC NEW WORLD CENTRE',
#  'OCBC NEWTON FOOD CENTRE',
#  'OCBC NEWTON MRT STATION',
#  'OCBC NEX',
#  'OCBC NG TENG FONG HOSPITAL',
#  'OCBC NGEE ANN CITY',
#  'OCBC NICOLL HIGHWAY MRT',
#  'OCBC NORTH BRACH',
#  'OCBC NOVENA MRT',
#  'OCBC NUH - FAIRPRICE',
#  'OCBC NUS',
#  'OCBC NUS',
#  'OCBC NUS',
#  'OCBC NUS',
#  'OCBC NUS',
#  'OCBC NUS',
#  'OCBC NUS UNIVERSITY TOWN - CHEERS',
#  'OCBC NUS UNIVERSITY TOWN - CHEERS',
#  'OCBC OCBC CENTRE BRANCH',
#  'OCBC OCBC TAMPINES CENTRE TWO',
#  'OCBC ONAN ROAD - CHEERS',
#  'OCBC ONE - NORTH MRT',
#  'OCBC ORCHARD MRT',
#  'OCBC ORCHARDGATEWAY BRANCH',
#  'OCBC ORCHID COUNTRY CLUB - FAIRPRICE',
#  'OCBC OUR TAMPINES HUB - FAIRPRICE',
#  'OCBC OUTRAM PARK MRT',
#  'OCBC PARAGON',
#  'OCBC PARCO BUGIS JUNCTION',
#  'OCBC PARKLANE SHOPPING MALL',
#  'OCBC PARKWAY PARADE',
#  'OCBC PASIR RIS BUS INTERCHANGE',
#  'OCBC PASIR RIS DRIVE 4 - GIANT',
#  'OCBC PASIR RIS DRIVE 6 - 7 ELEVEN',
#  'OCBC PASIR RIS MRT',
#  'OCBC PASIR RIS WEST PLAZA',
#  'OCBC PASIR RIS WEST PLAZA - FAIRPRICE',
#  'OCBC PAYA LEBAR MRT',
#  'OCBC PAYA LEBAR MRT CC',
#  'OCBC PAYA LEBAR SQUARE',
#  'OCBC PENINSULA PLAZA',
#  "OCBC PEOPLE'S PARK CENTRE",
#  "OCBC PEOPLE'S PARK COMPLEX",
#  'OCBC PIONEER MALL',
#  'OCBC PIONEER MRT',
#  'OCBC PIONEER ROAD - ESSO STATION',
#  'OCBC PLAZA SINGAPURA',
#  'OCBC POTONG PASIR - FAIRPRICE',
#  'OCBC POTONG PASIR MRT',
#  'OCBC PROMENADE MRT',
#  'OCBC PUNGGOL BUS INTERCHANGE',
#  'OCBC PUNGGOL DRIVE - FAIRPRICE',
#  'OCBC PUNGGOL FIELD',
#  'OCBC PUNGGOL MRT',
#  'OCBC PUNGGOL PLAZA',
#  'OCBC PUNGGOL WATERWAY TERRACE - FAIRPRICE',
#  'OCBC QUEENSTOWN MRT',
#  'OCBC QUEENSWAY SHOPPING CENTRE',
#  'OCBC RAFFLES CITY SHOPPING CENTRE',
#  'OCBC RAFFLES PLACE MRT',
#  'OCBC REPUBLIC POLYTECHNIC',
#  'OCBC RESORT WORLD AT SENTOSA',
#  'OCBC RIVER VALLEY ROAD - 7 ELEVEN',
#  'OCBC RIVER VALLEY ROAD - FAIRPRICE',
#  'OCBC RIVERVALE MALL',
#  'OCBC RIVERVALE PLAZA',
#  'OCBC ROCHER MRT',
#  'OCBC SCOTTS SQUARE',
#  'OCBC SELETAR MALL - FAIRPRICE',
#  'OCBC SEMBAWANG MRT',
#  'OCBC SEMBAWANG SHOPPING CENTRE',
#  'OCBC SEMBAWANG WAY - FAIRPRICE',
#  'OCBC SENG POH ROAD - 7 ELEVEN',
#  'OCBC SENGKANG BUS INTERCHANGE',
#  'OCBC SENJA ROAD - FAIRPRICE',
#  'OCBC SENTOSA',
#  'OCBC SENTOSA COVE',
#  'OCBC SERANGGON CENTRAL DRIVE - FAIRPRICE',
#  'OCBC SERANGGOON GARDEN BRANCH',
#  'OCBC SERANGOON AVE 3 - 7 ELEVEN',
#  'OCBC SERANGOON BUS INTERCHANGE',
#  'OCBC SERANGOON MRT',
#  'OCBC SERANGOON NORTH AVE 1 - FAIRPRICE',
#  'OCBC SERANGOON NORTH AVE 5 - SHENG SIONG',
#  'OCBC SERANGOON ROAD - 7 ELEVEN',
#  'OCBC SHAW CENTRE',
#  'OCBC SHAW PLAZA - TWIN HEIGHTS',
#  'OCBC SHUN LI INDUSTRIAL PARK',
#  'OCBC SILAT AVE - FAIRPRICE',
#  'OCBC SIM LIM SQUARE',
#  'OCBC SIM LIM TOWER',
#  'OCBC SIMEI MRT',
#  'OCBC SIMET STREET 3',
#  'OCBC SIMS PLACE',
#  'OCBC SINGAPORE GENERAL HOSPITAL',
#  'OCBC SINGAPORE INSTITUTE OF MANAGEMENT',
#  'OCBC SINGAPORE POLYTECHNIC',
#  'OCBC SINGAPORE POLYTECHNIC FRANK STORE',
#  'OCBC SINGAPORE PRESS HOLDINGS',
#  'OCBC SINGAPORE UNIVERSITY OF TECHNOLOGY AND DESIGN',
#  'OCBC SIXTH AVENUE - 7 ELEVEN',
#  'OCBC SIXTHAVENUE BRANCH',
#  'OCBC SMU BRANCH',
#  'OCBC SOUTH BRIDGE ROAD - FOOK HAI BULDING',
#  'OCBC SOUTH WOODLANDS DRIVE - FAIRPRICE',
#  'OCBC SQUARE 2 - FAIRPRICE',
#  'OCBC STADIUM STATION',
#  'OCBC STAMFORD ROAD - CHEERS',
#  'OCBC STIRLING ROAD - FAIRPRICE',
#  'OCBC SUN PLAZA - FAIRPRICE',
#  'OCBC SUN PLAZA BRANCH',
#  'OCBC SUNSHINE PLACE',
#  'OCBC SUNTECT CITY',
#  'OCBC TAI SENG MRT',
#  'OCBC TAMAN JURONG SHOPPING CENTRE',
#  'OCBC TAMPINES 1',
#  'OCBC TAMPINES AVE 1 - CHEERS',
#  'OCBC TAMPINES BRANCH',
#  'OCBC TAMPINES BUS INTERCHANGE',
#  'OCBC TAMPINES CENTRAL 1',
#  'OCBC TAMPINES CENTRAL COUMMUNITY CENTRE',
#  'OCBC TAMPINES CENTRE TWO',
#  'OCBC TAMPINES MRT',
#  'OCBC TAMPINES STREE 11 - FAIRPRICE',
#  'OCBC TAMPINES STREET 11 - 7 ELEVEN',
#  'OCBC TAMPINES STREET 11 - FAIRPRICE',
#  'OCBC TAMPINES STREET 21',
#  'OCBC TAMPINES STREET 21',
#  'OCBC TAMPINES STREET 44',
#  'OCBC TAMPINES STREET 81 - PRIME SUPERMARKET',
#  'OCBC TAN TOCK SENG HOSPITAL',
#  'OCBC TANAH MERAH FERRY TERMINAL',
#  'OCBC TANAH MERAH MRT',
#  'OCBC TANG PLAZA',
#  'OCBC TANGJONG PAGAR PLAZA',
#  'OCBC TANGLIN MALL',
#  'OCBC TANJONG KATONG ROAD - 7 ELEVEN',
#  'OCBC TANJONG PAGAR MRT',
#  'OCBC TANJONG PAGAR PLAZA - 7 ELEVEN',
#  'OCBC TANJONG PAGAR ROAD',
#  'OCBC TEBAN GARDENS ROAD',
#  'OCBC TEBAN PLACE',
#  'OCBC TECK WHYE LANE - FAIRPRICE',
#  'OCBC TELOK BLANGAH MRT',
#  'OCBC TELOK BLANGAH STREET 32 - FAIRPRICE',
#  'OCBC THE CATHAY',
#  'OCBC THE CENTRAL',
#  'OCBC THE CENTREPOINT',
#  'OCBC THE CLEMENTI MALL',
#  'OCBC THE SIGNATURE',
#  'OCBC THE STAR VISTA',
#  'OCBC THOMSON BRANCH',
#  'OCBC THOMSON PLAZA',
#  'OCBC TIONG BAHRU MRT',
#  'OCBC TIONG BAHRU PLAZA BRANCH',
#  'OCBC TOA PAYOH BUS INTERCHANGE',
#  'OCBC TOA PAYOH CENTRAL BRANCH',
#  'OCBC TOA PAYOH LORONG 1',
#  'OCBC TOA PAYOH LORONG 1 - 7 ELEVEN',
#  'OCBC TOA PAYOH LORONG 2 - ESSO STATION',
#  'OCBC TOA PAYOH LORONG 4 - FAIRPRICE',
#  'OCBC TOA PAYOH LORONG 6 - 7 ELEVEN',
#  'OCBC TOA PAYOH LORONG 6 - FAIRPRICE',
#  'OCBC TOA PAYOH LORONG 8',
#  'OCBC TOA PAYOH MRT',
#  'OCBC TOWNER ROAD - 7 ELEVEN',
#  'OCBC UBI AVENUE 1 - GIANT',
#  'OCBC UBI BUSINESS BANKING CENTRE',
#  'OCBC UPPER ALJUNIED ROAD - PRIME SUPERMARKET',
#  'OCBC UPPER BOON KENG ROAD',
#  'OCBC UPPER BOON KENG ROAD - FAIRPRICE',
#  'OCBC UPPER THOMSON ROAD - 7 ELEVEN',
#  'OCBC UPPER THOMSON ROAD - 7 ELEVEN',
#  'OCBC UPPER THOMSON ROAD - ESSO STATION',
#  'OCBC V HOTEL',
#  'OCBC VISTA POINT',
#  'OCBC VIVOCITY FRANK STORE',
#  'OCBC WATERWAY POINT - FAIRPRICE',
#  'OCBC WATERWAY POINT BRANCH',
#  'OCBC WEST COAST DRIVE - 7 ELEVEN',
#  'OCBC WEST COAST DRIVE - FAIRPRICE',
#  'OCBC WEST COAST PLAZA',
#  'OCBC WESTGATE',
#  'OCBC WHITE SANDS',
#  'OCBC WISMA ATRIA',
#  'OCBC WOODLANDS AVE 1 - FAIRPRICE',
#  'OCBC WOODLANDS AVE 3 - FAIRPRICE',
#  'OCBC WOODLANDS BRANCH',
#  'OCBC WOODLANDS DRIVE 50 - FAIRPRICE',
#  'OCBC WOODLANDS MART',
#  'OCBC WOODLANDS MRT',
#  'OCBC WOODLANDS NORTH PLAZA',
#  'OCBC WOODLANDS TEMPORARY BUS INTERCHANGE',
#  'OCBC YEW TEE MRT',
#  'OCBC YEW TEE SQAURE',
#  'OCBC YISHUN AVE 5 - 7 ELEVEN',
#  'OCBC YISHUN CENTRAL - CHEERS',
#  'OCBC YISHUN MRT',
#  'OCBC YISHUN RING ROAD',
#  'OCBC YISHUN RING ROAD',
#  'OCBC YISHUN RING ROAD',
#  'OCBC YISHUN RING ROAD - 7 ELEVEN',
#  'OCBC YISHUN RING ROAD - CALTEX STATION',
#  'OCBC YISHUN RING ROAD - FAIRPRICE',
#  'OCBC YISHUN RING ROAD - FAIRPRICE',
#  'OCBC YISHUN ST 22 - 7 ELEVEN',
#  'OCBC YISHUN STREET 72',
#  'OCBC YISHUN TEMP BUS INTERCHANGE',
#  'OCBC YUAN CHING ROAD - SHENG SIONG SUPERMARKET',
#  'OCBC YUNG KUANG ROAD - FAIRPRICE',
#  'OCBC ZHONGSHAN PARK - FAIRPRICE']

# %%
len(set(ocbc_addresses)), len(set(ocbc_atms)), len(set(ocbc_addresses) - set(ocbc_atms))
# Out:
# (525, 485, 220)

# %%
import re

def strings_match(s1, s2, allowed_substitutions):
    map_of_substitutions = {
        ' ': '[^A-Za-z0-9]*',
        '-': '[^A-Za-z0-9]*',
    }
    
    for ls in allowed_substitutions:
        for word in ls:
            if word:
                map_of_substitutions[word] = '(' + '|'.join([re.escape(w) for w in ls]) + ')'
    
    parts = re.split("\\b", s1)

    final_re = []
    for p in parts:
        if p in map_of_substitutions:
            final_re.append(map_of_substitutions[p])
        else:
            final_re.append(re.escape(p))

    # print(''.join(final_re))
    return re.search('^' + ''.join(final_re) + '$', s2)

STANDARD_SUBSTITUTIONS = [
    ['ST', 'STREET'],
    ['RD', 'ROAD'],
    ['AVE', 'AVENUE'],
    ['STATION', ''],
]

strings_match('BEDOK SOUTH MRT STATION', 'BEDOK SOUTH MRT ', STANDARD_SUBSTITUTIONS)
# Out:
# <re.Match object; span=(0, 16), match='BEDOK SOUTH MRT '>

# %%
len(set([
    a
    for a in ocbc_addresses
    if not any([strings_match(a, b, STANDARD_SUBSTITUTIONS) for b in ocbc_atms])
]))
# Out:
# 102
